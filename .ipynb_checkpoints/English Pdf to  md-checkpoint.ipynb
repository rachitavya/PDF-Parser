# %% [markdown]
# ## Install libraries

# %%
# !git clone https://github.com/VikParuchuri/marker.git
# Out:
# Cloning into 'marker'...
# remote: Enumerating objects: 498, done.
# remote: Counting objects: 100% (69/69), done.
# remote: Compressing objects: 100% (50/50), done.
# remote: Total 498 (delta 27), reused 35 (delta 14), pack-reused 429
# Receiving objects: 100% (498/498), 943.77 KiB | 5.52 MiB/s, done.
# Resolving deltas: 100% (326/326), done.

# %%
# %%capture

# !sudo apt-get update
# !apt-get install poppler-utils
# !apt-get install -y tesseract-ocr
# !apt-get install -y tesseract-ocr-hin
# !pip install pytesseract
# !pip install PyMuPDF
# !pip install ftfy
# !pip install gdown
# !pip install pdf2image
# !apt-get install -y ghostscript

# %%
# %%capture

# !pip install python-magic
# !pip install nougat-ocr
# !pip install thefuzz
# !pip install pyspellchecker
# !pip install ocrmypdf
# !pip install pydantic-settings
# !pip install python-dotenv
# !pip install pydantic==2.0
# !pip install fastapi
# !pip install keleido
# !pip install python-multipart
# !pip install uvicorn
# !pip install cohere
# !pip install openai
# !pip install tiktoken

# %%
import os
os.environ["TESSDATA_PREFIX"] = "/usr/share/tesseract-ocr/4.00/tessdata"
import fitz

# %% [markdown]
# ## Lets start

# %%
import os
os.environ["PATH"] += os.pathsep + "/root/.local/bin"

# %%
import torch
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
# !apt-get install -y tesseract-ocr tesseract-ocr-eng
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# tesseract-ocr is already the newest version (4.1.1-2.1build1).
# tesseract-ocr-eng is already the newest version (1:4.00~git30-7274cfa-1.1).
# tesseract-ocr-eng set to manually installed.
# 0 upgraded, 0 newly installed, 0 to remove and 29 not upgraded.

# %%
import os
os.environ["TESSDATA_PREFIX"] = "/usr/share/tesseract-ocr/4.00/tessdata"
import fitz

# %%
# %cd marker
# Out:
# /content/marker

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# !python convert_single.py '/content/NFSM12102018.pdf' '/content/drive/MyDrive/UPLift/English_pdfs/NFSM12102018.md' --parallel_factor 1 --max_pages 251
# Out:
# 2023-12-03 05:17:48.054022: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-03 05:17:48.054091: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-03 05:17:48.054125: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-03 05:17:49.592364: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# preprocessor_config.json: 100% 502/502 [00:00<00:00, 2.38MB/s]
# tokenizer_config.json: 100% 1.61k/1.61k [00:00<00:00, 7.12MB/s]
# vocab.json: 100% 798k/798k [00:00<00:00, 14.1MB/s]
# ...

# %%
# !python convert_single.py '/content/FARMER PRODUCER ORGANISATIONS.pdf' '/content/drive/MyDrive/UPLift/English_pdfs/FARMER PRODUCER ORGANISATIONS.md' --parallel_factor 1 --max_pages 158
# Out:
# 2023-12-03 05:21:10.361148: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-03 05:21:10.361265: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-03 05:21:10.361371: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-03 05:21:12.482025: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# ...

# %%
# !python convert_single.py '/content/RevisedPM-KISANOperationalGuidelines(English).pdf' '/content/drive/MyDrive/UPLift/English_pdfs/RevisedPM-KISANOperationalGuidelines(English).md' --parallel_factor 1 --max_pages 20
# Out:
# 2023-12-03 05:48:26.013549: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-03 05:48:26.013617: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-03 05:48:26.013660: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-03 05:48:27.902962: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# ...

# %%
# !python convert_single.py '/content/Revised_Operational_Guidelines.pdf' '/content/drive/MyDrive/UPLift/English_pdfs/Revised_Operational_Guidelines.md' --parallel_factor 1 --max_pages 100
# Out:
# 2023-12-03 05:51:10.820817: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-03 05:51:10.820885: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-03 05:51:10.820941: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-03 05:51:12.837941: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# ...

# %%
# !python convert_single.py '/content/UGPs-Organic FarmingTechnologies and Strategies.pdf' '/content/drive/MyDrive/UPLift/English_pdfs/UGPs-Organic FarmingTechnologies and Strategies.md' --parallel_factor 1 --max_pages 19
# Out:
# 2023-12-03 07:02:56.195041: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-03 07:02:56.195128: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-03 07:02:56.195183: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-03 07:02:59.137937: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# ...

# %%
# !python convert_single.py '/content/FPO_Scheme_Guidelines_FINAL_English.pdf' '/content/drive/MyDrive/UPLift/English_pdfs/FPO_Scheme_Guidelines_FINAL_English.md' --parallel_factor 1 --max_pages 70
# Out:
# 2023-12-03 07:08:50.040337: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-03 07:08:50.040407: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-03 07:08:50.040457: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-03 07:08:52.036770: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# ...

# %%
file_path = '/content/Natural_Farming_Kharif_Booklet.md'  # Replace 'yourfile.md' with your file name
with open(file_path, 'r', encoding='utf-8') as file:  # You can change encoding if needed
    content = file.read()
print(content)
# Out:
# ## प्राकृतिक तकनीक द्वारा बाजरा की
#
# प्रदेश में बाजरे की वर्ष 2022 के आंकड़े से लगभग 9.80 लाख हेक्टेयर है।
# प्रदेश में बाजरे की खेती से लगभग 50 लाख मीट्रिक टन उत्पादन प्राप्त हो रहा है। कम
# वर्षा
# मेंइसकी खेती सफल है 40-50 से०मी0 वार्षिक वर्षा वाले
# क्षेत्रों
# मेंइसकी खेती
# सफलता पूर्वक की जा सकती है। बाजरा व्यापक रूप से मानव भोजन एवं चारे के रूप
# में उगाया जाता
# हैं।
# प्रदेश
# में बाजरे की खेती बुन्देलखण्ड
# क्षेत्र, आगरा, बरेली, एवं
# कानपुर मण्डलों में होती है।
# प्रजातियों
# काचयनः अच्छी उपज प्राप्त करने लिए उननतिशील प्रजातियों का शुद्ध बीज
# ही बोना चाहिए। लेकिन कुछ किसमें ऐसी है जिन्हें लोग पशुओं के चारे के लिए उगाते हैं।
# उत्तर
# प्रदेश
# में बाजरे की
# प्रजातियों उपलब्ध
# है
# उनमें
# से
# प्रमुख है-
# पूसा
# कम्पोजिट-704, धन-शक्ति, पूसा कम्पोजिट-443
# |
# भूमि का चुनाव: बाजरा के लिए हल्की या दोमट बलुई मिट्टी उपयुक्त होती है। भूमि का जल निकास उत्तम होना आवश्यक है एवं जिस भूमि
# में पहली बार प्राकृतिक खेती
# करनी है उस मिट्टी की जांच करवा लेनी चाहिए
# |
# ...
